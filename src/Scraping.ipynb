# %%
import requests

verbose = True

base_url = 'http://www.gandhiashramsevagram.org/gandhi-literature/mahatma-gandhi-collected-works-volume-{}.pdf'
base_gandhi_file = '../corpus/gandhi/pdf/volume_{}.pdf'
base_gandhi_text = '../corpus/gandhi/text/volume_{}.txt'
base_clean_file = '../corpus/gandhi/text/clean_volume_{}.txt'
gandhi = '../corpus/gandhi/gandhi.txt'

def donwload_pdf(url, save_name):
    response = requests.get(url)
    
    with open(save_name, 'wb') as f:
        f.write(response.content)

# %%
# Download each of the 98 pdfs from the site http://www.gandhiashramsevagram.org/
for i in range(1, 99):
    save_file = base_gandhi_file.format(i)
    
    if verbose:
        print('Downloading', save_file + '...')
    
    donwload_pdf(base_url.format(i), save_file)
# Out:
# Downloading ../corpus/gandhi/pdf/volume_1.pdf...
# Downloading ../corpus/gandhi/pdf/volume_2.pdf...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-23ca3df49bd8> in <module>()
#       6         print('Downloading', save_file + '...')
#       7
# ----> 8     donwload_pdf(base_url.format(i), save_file)
#
# <ipython-input-2-f113af6a38a3> in donwload_pdf(url, save_name)
#       7
#       8 def donwload_pdf(url, save_name):
# ----> 9     response = requests.get(url)
#      10
#      11     with open(save_name, 'wb') as f:
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/envs/nlp/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/anaconda3/envs/nlp/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/envs/nlp/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/envs/nlp/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import subprocess

for i in range(1, 99):
    
    gandhi_text_file = base_gandhi_text.format(i)
    
    if verbose:
        print('Converting PDF to', gandhi_text_file + '...')
    
    # Convert the ith pdf into a txt file and save it in the txt/ directory
    result = subprocess.run(['pdftotext', base_gandhi_file.format(i), gandhi_text_file])
    print(result)
# Out:
# Converting PDF to ../corpus/gandhi/text/volume_1.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_1.pdf', '../corpus/gandhi/text/volume_1.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_2.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_2.pdf', '../corpus/gandhi/text/volume_2.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_3.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_3.pdf', '../corpus/gandhi/text/volume_3.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_4.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_4.pdf', '../corpus/gandhi/text/volume_4.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_5.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_5.pdf', '../corpus/gandhi/text/volume_5.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_6.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_6.pdf', '../corpus/gandhi/text/volume_6.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_7.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_7.pdf', '../corpus/gandhi/text/volume_7.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_8.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_8.pdf', '../corpus/gandhi/text/volume_8.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_9.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_9.pdf', '../corpus/gandhi/text/volume_9.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_10.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_10.pdf', '../corpus/gandhi/text/volume_10.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_11.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_11.pdf', '../corpus/gandhi/text/volume_11.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_12.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_12.pdf', '../corpus/gandhi/text/volume_12.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_13.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_13.pdf', '../corpus/gandhi/text/volume_13.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_14.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_14.pdf', '../corpus/gandhi/text/volume_14.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_15.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_15.pdf', '../corpus/gandhi/text/volume_15.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_16.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_16.pdf', '../corpus/gandhi/text/volume_16.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_17.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_17.pdf', '../corpus/gandhi/text/volume_17.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_18.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_18.pdf', '../corpus/gandhi/text/volume_18.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_19.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_19.pdf', '../corpus/gandhi/text/volume_19.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_20.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_20.pdf', '../corpus/gandhi/text/volume_20.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_21.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_21.pdf', '../corpus/gandhi/text/volume_21.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_22.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_22.pdf', '../corpus/gandhi/text/volume_22.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_23.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_23.pdf', '../corpus/gandhi/text/volume_23.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_24.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_24.pdf', '../corpus/gandhi/text/volume_24.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_25.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_25.pdf', '../corpus/gandhi/text/volume_25.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_26.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_26.pdf', '../corpus/gandhi/text/volume_26.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_27.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_27.pdf', '../corpus/gandhi/text/volume_27.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_28.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_28.pdf', '../corpus/gandhi/text/volume_28.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_29.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_29.pdf', '../corpus/gandhi/text/volume_29.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_30.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_30.pdf', '../corpus/gandhi/text/volume_30.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_31.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_31.pdf', '../corpus/gandhi/text/volume_31.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_32.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_32.pdf', '../corpus/gandhi/text/volume_32.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_33.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_33.pdf', '../corpus/gandhi/text/volume_33.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_34.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_34.pdf', '../corpus/gandhi/text/volume_34.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_35.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_35.pdf', '../corpus/gandhi/text/volume_35.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_36.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_36.pdf', '../corpus/gandhi/text/volume_36.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_37.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_37.pdf', '../corpus/gandhi/text/volume_37.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_38.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_38.pdf', '../corpus/gandhi/text/volume_38.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_39.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_39.pdf', '../corpus/gandhi/text/volume_39.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_40.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_40.pdf', '../corpus/gandhi/text/volume_40.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_41.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_41.pdf', '../corpus/gandhi/text/volume_41.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_42.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_42.pdf', '../corpus/gandhi/text/volume_42.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_43.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_43.pdf', '../corpus/gandhi/text/volume_43.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_44.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_44.pdf', '../corpus/gandhi/text/volume_44.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_45.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_45.pdf', '../corpus/gandhi/text/volume_45.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_46.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_46.pdf', '../corpus/gandhi/text/volume_46.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_47.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_47.pdf', '../corpus/gandhi/text/volume_47.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_48.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_48.pdf', '../corpus/gandhi/text/volume_48.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_49.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_49.pdf', '../corpus/gandhi/text/volume_49.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_50.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_50.pdf', '../corpus/gandhi/text/volume_50.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_51.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_51.pdf', '../corpus/gandhi/text/volume_51.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_52.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_52.pdf', '../corpus/gandhi/text/volume_52.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_53.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_53.pdf', '../corpus/gandhi/text/volume_53.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_54.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_54.pdf', '../corpus/gandhi/text/volume_54.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_55.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_55.pdf', '../corpus/gandhi/text/volume_55.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_56.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_56.pdf', '../corpus/gandhi/text/volume_56.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_57.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_57.pdf', '../corpus/gandhi/text/volume_57.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_58.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_58.pdf', '../corpus/gandhi/text/volume_58.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_59.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_59.pdf', '../corpus/gandhi/text/volume_59.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_60.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_60.pdf', '../corpus/gandhi/text/volume_60.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_61.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_61.pdf', '../corpus/gandhi/text/volume_61.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_62.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_62.pdf', '../corpus/gandhi/text/volume_62.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_63.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_63.pdf', '../corpus/gandhi/text/volume_63.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_64.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_64.pdf', '../corpus/gandhi/text/volume_64.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_65.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_65.pdf', '../corpus/gandhi/text/volume_65.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_66.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_66.pdf', '../corpus/gandhi/text/volume_66.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_67.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_67.pdf', '../corpus/gandhi/text/volume_67.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_68.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_68.pdf', '../corpus/gandhi/text/volume_68.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_69.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_69.pdf', '../corpus/gandhi/text/volume_69.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_70.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_70.pdf', '../corpus/gandhi/text/volume_70.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_71.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_71.pdf', '../corpus/gandhi/text/volume_71.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_72.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_72.pdf', '../corpus/gandhi/text/volume_72.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_73.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_73.pdf', '../corpus/gandhi/text/volume_73.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_74.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_74.pdf', '../corpus/gandhi/text/volume_74.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_75.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_75.pdf', '../corpus/gandhi/text/volume_75.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_76.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_76.pdf', '../corpus/gandhi/text/volume_76.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_77.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_77.pdf', '../corpus/gandhi/text/volume_77.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_78.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_78.pdf', '../corpus/gandhi/text/volume_78.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_79.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_79.pdf', '../corpus/gandhi/text/volume_79.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_80.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_80.pdf', '../corpus/gandhi/text/volume_80.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_81.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_81.pdf', '../corpus/gandhi/text/volume_81.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_82.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_82.pdf', '../corpus/gandhi/text/volume_82.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_83.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_83.pdf', '../corpus/gandhi/text/volume_83.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_84.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_84.pdf', '../corpus/gandhi/text/volume_84.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_85.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_85.pdf', '../corpus/gandhi/text/volume_85.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_86.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_86.pdf', '../corpus/gandhi/text/volume_86.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_87.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_87.pdf', '../corpus/gandhi/text/volume_87.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_88.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_88.pdf', '../corpus/gandhi/text/volume_88.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_89.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_89.pdf', '../corpus/gandhi/text/volume_89.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_90.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_90.pdf', '../corpus/gandhi/text/volume_90.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_91.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_91.pdf', '../corpus/gandhi/text/volume_91.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_92.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_92.pdf', '../corpus/gandhi/text/volume_92.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_93.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_93.pdf', '../corpus/gandhi/text/volume_93.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_94.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_94.pdf', '../corpus/gandhi/text/volume_94.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_95.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_95.pdf', '../corpus/gandhi/text/volume_95.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_96.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_96.pdf', '../corpus/gandhi/text/volume_96.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_97.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_97.pdf', '../corpus/gandhi/text/volume_97.txt'], returncode=0)
# Converting PDF to ../corpus/gandhi/text/volume_98.txt...
# CompletedProcess(args=['pdftotext', '../corpus/gandhi/pdf/volume_98.pdf', '../corpus/gandhi/text/volume_98.txt'], returncode=0)

# %%
import re, codecs

def check_regex(regex, text):

    matches = re.finditer(regex, text)

    for match in matches:
        print(match.group(0))
        print('---')

        
def clean_text():

    # Define the patterns we will match that don't depend on the volume
    collected_works_page_break = re.compile('[\n\s]*[0-9]*[\n\s]*THE COLLECTED WORKS OF.*[\n\s]*\f')
    headers_and_footers = re.compile('\n[a-z|0-9].*[\n\s]+')
    description_of_text = re.compile('[\n\s]*.*photostat.*[\n\s]*')

    for i in range(1, 99):
        
        # Read the ith text file
        gandhi_text_file = codecs.open(base_gandhi_text.format(i), 'r', 'iso-8859-1')
        text = gandhi_text_file.read()

        # Define the regex that depend on the volume number
        vol_page_break = re.compile('VOL\.\s*{}.*[\n\s]*[0-9]*[\n\s]*\f'.format(i))
    
        # Successively remove all of the text matched by our patterns
        result1, n1 = re.subn(collected_works_page_break, '', text)
        result2, n2 = re.subn(vol_page_break, '', result1)
        result3, n3 = re.subn(headers_and_footers, '', result2)
        result4, n4 = re.subn(description_of_text, '', result3)

        # For debugging
#         check_regex(collected_works_page_break, text)
        
        if verbose:
            print('deletions:', n1, n2, n3, n4)
        
        clean_text = result4

        with open(base_clean_file.format(i), 'w') as clean_file:
            clean_file.write(clean_text)
        
        if verbose:
            print('wrote clean file to', base_clean_file.format(i))

clean_text()
print('Done')
# Out:
# deletions: 235 236 1009 25
# wrote clean file to ../corpus/gandhi/text/clean_volume_1.txt
# deletions: 242 42 903 112
# wrote clean file to ../corpus/gandhi/text/clean_volume_2.txt
# deletions: 252 253 834 21
# wrote clean file to ../corpus/gandhi/text/clean_volume_3.txt
# deletions: 240 241 900 22
# wrote clean file to ../corpus/gandhi/text/clean_volume_4.txt
# deletions: 246 247 1021 91
# wrote clean file to ../corpus/gandhi/text/clean_volume_5.txt
# deletions: 268 269 911 122
# wrote clean file to ../corpus/gandhi/text/clean_volume_6.txt
# deletions: 224 224 739 4
# wrote clean file to ../corpus/gandhi/text/clean_volume_7.txt
# deletions: 247 248 738 16
# wrote clean file to ../corpus/gandhi/text/clean_volume_8.txt
# deletions: 252 252 851 45
# wrote clean file to ../corpus/gandhi/text/clean_volume_9.txt
# deletions: 255 256 896 90
# wrote clean file to ../corpus/gandhi/text/clean_volume_10.txt
# deletions: 255 255 1036 165
# wrote clean file to ../corpus/gandhi/text/clean_volume_11.txt
# deletions: 243 243 1332 58
# wrote clean file to ../corpus/gandhi/text/clean_volume_12.txt
# deletions: 235 235 588 51
# wrote clean file to ../corpus/gandhi/text/clean_volume_13.txt
# deletions: 257 257 834 60
# wrote clean file to ../corpus/gandhi/text/clean_volume_14.txt
# deletions: 262 262 945 83
# wrote clean file to ../corpus/gandhi/text/clean_volume_15.txt
# deletions: 259 260 831 29
# wrote clean file to ../corpus/gandhi/text/clean_volume_16.txt
# deletions: 237 238 762 95
# wrote clean file to ../corpus/gandhi/text/clean_volume_17.txt
# deletions: 234 208 757 128
# wrote clean file to ../corpus/gandhi/text/clean_volume_18.txt
# deletions: 252 251 792 111
# wrote clean file to ../corpus/gandhi/text/clean_volume_19.txt
# deletions: 223 243 806 31
# wrote clean file to ../corpus/gandhi/text/clean_volume_20.txt
# deletions: 260 261 941 34
# wrote clean file to ../corpus/gandhi/text/clean_volume_21.txt
# deletions: 258 259 886 29
# wrote clean file to ../corpus/gandhi/text/clean_volume_22.txt
# deletions: 244 245 732 22
# wrote clean file to ../corpus/gandhi/text/clean_volume_23.txt
# deletions: 207 237 651 33
# wrote clean file to ../corpus/gandhi/text/clean_volume_24.txt
# deletions: 248 249 773 42
# wrote clean file to ../corpus/gandhi/text/clean_volume_25.txt
# deletions: 232 232 813 61
# wrote clean file to ../corpus/gandhi/text/clean_volume_26.txt
# deletions: 239 238 859 191
# wrote clean file to ../corpus/gandhi/text/clean_volume_27.txt
# deletions: 253 254 756 38
# wrote clean file to ../corpus/gandhi/text/clean_volume_28.txt
# deletions: 257 257 894 66
# wrote clean file to ../corpus/gandhi/text/clean_volume_29.txt
# deletions: 236 237 742 21
# wrote clean file to ../corpus/gandhi/text/clean_volume_30.txt
# deletions: 242 243 938 28
# wrote clean file to ../corpus/gandhi/text/clean_volume_31.txt
# deletions: 235 234 771 53
# wrote clean file to ../corpus/gandhi/text/clean_volume_32.txt
# deletions: 238 238 871 79
# wrote clean file to ../corpus/gandhi/text/clean_volume_33.txt
# deletions: 249 249 698 86
# wrote clean file to ../corpus/gandhi/text/clean_volume_34.txt
# deletions: 210 236 1017 179
# wrote clean file to ../corpus/gandhi/text/clean_volume_35.txt
# deletions: 254 255 1035 224
# wrote clean file to ../corpus/gandhi/text/clean_volume_36.txt
# deletions: 245 245 820 63
# wrote clean file to ../corpus/gandhi/text/clean_volume_37.txt
# deletions: 249 251 1052 149
# wrote clean file to ../corpus/gandhi/text/clean_volume_38.txt
# deletions: 249 249 884 192
# wrote clean file to ../corpus/gandhi/text/clean_volume_39.txt
# deletions: 250 251 723 65
# wrote clean file to ../corpus/gandhi/text/clean_volume_40.txt
# deletions: 247 248 866 266
# wrote clean file to ../corpus/gandhi/text/clean_volume_41.txt
# deletions: 237 238 904 192
# wrote clean file to ../corpus/gandhi/text/clean_volume_42.txt
# deletions: 263 263 1158 270
# wrote clean file to ../corpus/gandhi/text/clean_volume_43.txt
# deletions: 255 256 586 50
# wrote clean file to ../corpus/gandhi/text/clean_volume_44.txt
# deletions: 240 240 822 161
# wrote clean file to ../corpus/gandhi/text/clean_volume_45.txt
# deletions: 232 232 1119 121
# wrote clean file to ../corpus/gandhi/text/clean_volume_46.txt
# deletions: 233 234 967 199
# wrote clean file to ../corpus/gandhi/text/clean_volume_47.txt
# deletions: 264 265 1025 147
# wrote clean file to ../corpus/gandhi/text/clean_volume_48.txt
# deletions: 235 235 732 199
# wrote clean file to ../corpus/gandhi/text/clean_volume_49.txt
# deletions: 238 227 1033 354
# wrote clean file to ../corpus/gandhi/text/clean_volume_50.txt
# deletions: 224 239 917 177
# wrote clean file to ../corpus/gandhi/text/clean_volume_51.txt
# deletions: 239 238 1001 237
# wrote clean file to ../corpus/gandhi/text/clean_volume_52.txt
# deletions: 258 259 952 195
# wrote clean file to ../corpus/gandhi/text/clean_volume_53.txt
# deletions: 230 240 813 124
# wrote clean file to ../corpus/gandhi/text/clean_volume_54.txt
# deletions: 259 260 1007 251
# wrote clean file to ../corpus/gandhi/text/clean_volume_55.txt
# deletions: 233 233 932 193
# wrote clean file to ../corpus/gandhi/text/clean_volume_56.txt
# deletions: 223 224 936 228
# wrote clean file to ../corpus/gandhi/text/clean_volume_57.txt
# deletions: 248 248 1115 195
# wrote clean file to ../corpus/gandhi/text/clean_volume_58.txt
# deletions: 259 259 1029 192
# wrote clean file to ../corpus/gandhi/text/clean_volume_59.txt
# deletions: 258 258 995 164
# wrote clean file to ../corpus/gandhi/text/clean_volume_60.txt
# deletions: 247 247 1000 206
# wrote clean file to ../corpus/gandhi/text/clean_volume_61.txt
# deletions: 231 231 913 140
# wrote clean file to ../corpus/gandhi/text/clean_volume_62.txt
# deletions: 261 261 966 171
# wrote clean file to ../corpus/gandhi/text/clean_volume_63.txt
# deletions: 231 231 882 136
# wrote clean file to ../corpus/gandhi/text/clean_volume_64.txt
# deletions: 232 230 877 99
# wrote clean file to ../corpus/gandhi/text/clean_volume_65.txt
# deletions: 229 229 996 222
# wrote clean file to ../corpus/gandhi/text/clean_volume_66.txt
# deletions: 222 223 999 295
# wrote clean file to ../corpus/gandhi/text/clean_volume_67.txt
# deletions: 224 224 960 173
# wrote clean file to ../corpus/gandhi/text/clean_volume_68.txt
# deletions: 231 232 930 246
# wrote clean file to ../corpus/gandhi/text/clean_volume_69.txt
# deletions: 188 220 822 176
# wrote clean file to ../corpus/gandhi/text/clean_volume_70.txt
# deletions: 213 214 958 207
# wrote clean file to ../corpus/gandhi/text/clean_volume_71.txt
# deletions: 225 252 1064 217
# wrote clean file to ../corpus/gandhi/text/clean_volume_72.txt
# deletions: 230 231 992 266
# wrote clean file to ../corpus/gandhi/text/clean_volume_73.txt
# deletions: 230 231 857 223
# wrote clean file to ../corpus/gandhi/text/clean_volume_74.txt
# deletions: 239 239 986 86
# wrote clean file to ../corpus/gandhi/text/clean_volume_75.txt
# deletions: 219 219 995 167
# wrote clean file to ../corpus/gandhi/text/clean_volume_76.txt
# deletions: 219 219 868 121
# wrote clean file to ../corpus/gandhi/text/clean_volume_77.txt
# deletions: 225 152 951 184
# wrote clean file to ../corpus/gandhi/text/clean_volume_78.txt
# deletions: 240 241 954 181
# wrote clean file to ../corpus/gandhi/text/clean_volume_79.txt
# deletions: 246 246 1207 361
# wrote clean file to ../corpus/gandhi/text/clean_volume_80.txt
# deletions: 256 256 1181 212
# wrote clean file to ../corpus/gandhi/text/clean_volume_81.txt
# deletions: 211 209 862 134
# wrote clean file to ../corpus/gandhi/text/clean_volume_82.txt
# deletions: 237 238 872 80
# wrote clean file to ../corpus/gandhi/text/clean_volume_83.txt
# deletions: 239 239 999 139
# wrote clean file to ../corpus/gandhi/text/clean_volume_84.txt
# deletions: 187 235 1046 209
# wrote clean file to ../corpus/gandhi/text/clean_volume_85.txt
# deletions: 220 221 910 199
# wrote clean file to ../corpus/gandhi/text/clean_volume_86.txt
# deletions: 212 220 927 153
# wrote clean file to ../corpus/gandhi/text/clean_volume_87.txt
# deletions: 215 215 1043 166
# wrote clean file to ../corpus/gandhi/text/clean_volume_88.txt
# deletions: 232 232 940 87
# wrote clean file to ../corpus/gandhi/text/clean_volume_89.txt
# deletions: 226 226 1115 105
# wrote clean file to ../corpus/gandhi/text/clean_volume_90.txt
# deletions: 224 225 881 69
# wrote clean file to ../corpus/gandhi/text/clean_volume_91.txt
# deletions: 218 248 896 95
# wrote clean file to ../corpus/gandhi/text/clean_volume_92.txt
# deletions: 211 212 953 129
# wrote clean file to ../corpus/gandhi/text/clean_volume_93.txt
# deletions: 207 208 849 86
# wrote clean file to ../corpus/gandhi/text/clean_volume_94.txt
# deletions: 213 213 806 64
# wrote clean file to ../corpus/gandhi/text/clean_volume_95.txt
# deletions: 221 221 845 82
# wrote clean file to ../corpus/gandhi/text/clean_volume_96.txt
# deletions: 241 241 709 49
# wrote clean file to ../corpus/gandhi/text/clean_volume_97.txt
# deletions: 233 232 991 116
# wrote clean file to ../corpus/gandhi/text/clean_volume_98.txt
# Done

# %%
import time
time.time()
# Out:
# 1530737909.627785

# %%
# put everything into one big clean file

gandhi_file =  open(gandhi, 'w')

for i in range(1, 99):
    clean_text = open(base_clean_file.format(i), 'r').read()
    print(clean_text[:10])
    gandhi_file.write(clean_text)

    print('Wrote', base_clean_file.format(i), 'to', gandhi)
    
gandhi_file.close()
# Out:
# 1. A CONFE
# Wrote ../corpus/gandhi/text/clean_volume_1.txt to ../corpus/gandhi/gandhi.txt
# 1. INTERVI
# Wrote ../corpus/gandhi/text/clean_volume_2.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_3.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_4.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_5.txt to ../corpus/gandhi/gandhi.txt
# 1. CIRCULA
# Wrote ../corpus/gandhi/text/clean_volume_6.txt to ../corpus/gandhi/gandhi.txt
# 1. ROYAL A
# Wrote ../corpus/gandhi/text/clean_volume_7.txt to ../corpus/gandhi/gandhi.txt
# 1. LATE MR
# Wrote ../corpus/gandhi/text/clean_volume_8.txt to ../corpus/gandhi/gandhi.txt
# 1. SPEECH
# Wrote ../corpus/gandhi/text/clean_volume_9.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_10.txt to ../corpus/gandhi/gandhi.txt
# 1. JOHANNE
# Wrote ../corpus/gandhi/text/clean_volume_11.txt to ../corpus/gandhi/gandhi.txt
# 1. TO THE
# Wrote ../corpus/gandhi/text/clean_volume_12.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_13.txt to ../corpus/gandhi/gandhi.txt
# 1. CABLE T
# Wrote ../corpus/gandhi/text/clean_volume_14.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_15.txt to ../corpus/gandhi/gandhi.txt
# 1. INDIAN
# Wrote ../corpus/gandhi/text/clean_volume_16.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_17.txt to ../corpus/gandhi/gandhi.txt
# 1. SATYAGR
# Wrote ../corpus/gandhi/text/clean_volume_18.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_19.txt to ../corpus/gandhi/gandhi.txt
# 1. CONGRES
# Wrote ../corpus/gandhi/text/clean_volume_20.txt to ../corpus/gandhi/gandhi.txt
# 1. "PATH O
# Wrote ../corpus/gandhi/text/clean_volume_21.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_22.txt to ../corpus/gandhi/gandhi.txt
# 1. NOTES
# I
# Wrote ../corpus/gandhi/text/clean_volume_23.txt to ../corpus/gandhi/gandhi.txt
# 1. SPEECH
# Wrote ../corpus/gandhi/text/clean_volume_24.txt to ../corpus/gandhi/gandhi.txt
# 1. NOTES
# M
# Wrote ../corpus/gandhi/text/clean_volume_25.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_26.txt to ../corpus/gandhi/gandhi.txt
# 1. INTERVI
# Wrote ../corpus/gandhi/text/clean_volume_27.txt to ../corpus/gandhi/gandhi.txt
# 1. MY JAIL
# Wrote ../corpus/gandhi/text/clean_volume_28.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_29.txt to ../corpus/gandhi/gandhi.txt
# 1. SPEECH
# Wrote ../corpus/gandhi/text/clean_volume_30.txt to ../corpus/gandhi/gandhi.txt
# 1. WHAT SH
# Wrote ../corpus/gandhi/text/clean_volume_31.txt to ../corpus/gandhi/gandhi.txt
# 1. TELEGRA
# Wrote ../corpus/gandhi/text/clean_volume_32.txt to ../corpus/gandhi/gandhi.txt
# 1. STATEME
# Wrote ../corpus/gandhi/text/clean_volume_33.txt to ../corpus/gandhi/gandhi.txt
# 1. SATYAGR
# Wrote ../corpus/gandhi/text/clean_volume_34.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_35.txt to ../corpus/gandhi/gandhi.txt
# 1. NOTES
# S
# Wrote ../corpus/gandhi/text/clean_volume_36.txt to ../corpus/gandhi/gandhi.txt
# 1. PROSTIT
# Wrote ../corpus/gandhi/text/clean_volume_37.txt to ../corpus/gandhi/gandhi.txt
# 1. SPEECH
# Wrote ../corpus/gandhi/text/clean_volume_38.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_39.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_40.txt to ../corpus/gandhi/gandhi.txt
# 1. SPEECH
# Wrote ../corpus/gandhi/text/clean_volume_41.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_42.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_43.txt to ../corpus/gandhi/gandhi.txt
# 1. TELEGRA
# Wrote ../corpus/gandhi/text/clean_volume_44.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_45.txt to ../corpus/gandhi/gandhi.txt
# 1. WHAT CO
# Wrote ../corpus/gandhi/text/clean_volume_46.txt to ../corpus/gandhi/gandhi.txt
# 1.CARDING
# Wrote ../corpus/gandhi/text/clean_volume_47.txt to ../corpus/gandhi/gandhi.txt
# 1. NOTES
# I
# Wrote ../corpus/gandhi/text/clean_volume_48.txt to ../corpus/gandhi/gandhi.txt
# 1. NOTES
# D
# Wrote ../corpus/gandhi/text/clean_volume_49.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_50.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_51.txt to ../corpus/gandhi/gandhi.txt
# 1. TELEGRA
# Wrote ../corpus/gandhi/text/clean_volume_52.txt to ../corpus/gandhi/gandhi.txt
# 1. SUPERST
# Wrote ../corpus/gandhi/text/clean_volume_53.txt to ../corpus/gandhi/gandhi.txt
# 1. INTERVI
# Wrote ../corpus/gandhi/text/clean_volume_54.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_55.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_56.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_57.txt to ../corpus/gandhi/gandhi.txt
# 1. STATEME
# Wrote ../corpus/gandhi/text/clean_volume_58.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_59.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_60.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_61.txt to ../corpus/gandhi/gandhi.txt
# 1. A CASE
# Wrote ../corpus/gandhi/text/clean_volume_62.txt to ../corpus/gandhi/gandhi.txt
# 1. MAY THE
# Wrote ../corpus/gandhi/text/clean_volume_63.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_64.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_65.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_66.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_67.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_68.txt to ../corpus/gandhi/gandhi.txt
# 1. A GREAT
# Wrote ../corpus/gandhi/text/clean_volume_69.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_70.txt to ../corpus/gandhi/gandhi.txt
# 1. INTERVI
# Wrote ../corpus/gandhi/text/clean_volume_71.txt to ../corpus/gandhi/gandhi.txt
# 1. SPEECH
# Wrote ../corpus/gandhi/text/clean_volume_72.txt to ../corpus/gandhi/gandhi.txt
# 1. NOTE TO
# Wrote ../corpus/gandhi/text/clean_volume_73.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_74.txt to ../corpus/gandhi/gandhi.txt
# 1. RAJKOT
#
# Wrote ../corpus/gandhi/text/clean_volume_75.txt to ../corpus/gandhi/gandhi.txt
# 1. TELEGRA
# Wrote ../corpus/gandhi/text/clean_volume_76.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_77.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_78.txt to ../corpus/gandhi/gandhi.txt
# 1. MYSORE
# Wrote ../corpus/gandhi/text/clean_volume_79.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_80.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_81.txt to ../corpus/gandhi/gandhi.txt
# 1. ADIVASI
# Wrote ../corpus/gandhi/text/clean_volume_82.txt to ../corpus/gandhi/gandhi.txt
# 1. KHADI I
# Wrote ../corpus/gandhi/text/clean_volume_83.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_84.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_85.txt to ../corpus/gandhi/gandhi.txt
# 1. FOREWOR
# Wrote ../corpus/gandhi/text/clean_volume_86.txt to ../corpus/gandhi/gandhi.txt
# 1. TELEGRA
# Wrote ../corpus/gandhi/text/clean_volume_87.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_88.txt to ../corpus/gandhi/gandhi.txt
# 1. TELEGRA
# Wrote ../corpus/gandhi/text/clean_volume_89.txt to ../corpus/gandhi/gandhi.txt
# 1. TWO REQ
# Wrote ../corpus/gandhi/text/clean_volume_90.txt to ../corpus/gandhi/gandhi.txt
# 1. AN ANAL
# Wrote ../corpus/gandhi/text/clean_volume_91.txt to ../corpus/gandhi/gandhi.txt
# 1. COMPENS
# Wrote ../corpus/gandhi/text/clean_volume_92.txt to ../corpus/gandhi/gandhi.txt
# 1. TALK TO
# Wrote ../corpus/gandhi/text/clean_volume_93.txt to ../corpus/gandhi/gandhi.txt
# 1. A LETTE
# Wrote ../corpus/gandhi/text/clean_volume_94.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_95.txt to ../corpus/gandhi/gandhi.txt
# 1. LETTER
# Wrote ../corpus/gandhi/text/clean_volume_96.txt to ../corpus/gandhi/gandhi.txt
# 1. HINDUST
# Wrote ../corpus/gandhi/text/clean_volume_97.txt to ../corpus/gandhi/gandhi.txt
# 1. GIVE AN
# Wrote ../corpus/gandhi/text/clean_volume_98.txt to ../corpus/gandhi/gandhi.txt
